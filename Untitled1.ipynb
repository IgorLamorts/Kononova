# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures

# %%
def metrics(X_train, X_test, y_train, y_test, y_pred, model):
    RMSE = [mean_squared_error(y_train, model.predict(X_train),squared=False), mean_squared_error(y_test, y_pred, squared=False)]
    R2 = [model.score(X_train, y_train), model.score(X_test, y_test)]
    results = {'RMSE': RMSE, 'R2':R2}
    return pd.DataFrame(results, index=['Train', 'Test'])

# %%
df = pd.read_excel("Variant7.xlsx", engine='openpyxl')
df.head()
# Out:
#    Площадь загальна кв.м  Этаж  Количество касс    Тип  \
# 0                    9.0     1                1  Light
# 1                   30.0     1                1  Light
# 2                   15.0     1                1  light
# 3                   20.0     1                1  light
# 4                   30.0     1                1  light
#
#    Кількість відгуків в гуглі  Количество чеков  \
# 0                         NaN             659.0
# 1                         8.0            1518.0
# 2                         NaN             476.0
# 3                         NaN            1310.0
# 4                         NaN            2029.0
#
#    Среднее количество единиц в чеке  Середній дохід населення  \
# 0                              1.56                   15610.0
# 1                              2.03                   12600.0
# 2                              1.81                   12600.0
# 3                              2.18                   13930.0
# 4                              1.63                   16030.0
#
#    Населення середнє  Прогулянкова зона  Якість покриття перед магазином  \
# 0            11298.0                  0                                0
# 1            18903.0                  0                                0
# 2            20252.0                  0                                0
# 3             2540.0                  0                                0
# 4             6896.0                  0                                0
#
#    Стихійна торгівля  Зона пікніка  Церква
# 0                  0             0       1
# 1                  0             0       0
# 2                  0             0       0
# 3                  0             0       0
# 4                  0             0       0

# %%
df.shape
# Out:
# (69, 14)

# %%
df.dtypes
# Out:
# Площадь загальна кв.м               float64
# Этаж                                  int64
# Количество касс                       int64
# Тип                                  object
# Кількість відгуків в гуглі          float64
# Количество чеков                    float64
# Среднее количество единиц в чеке    float64
# Середній дохід населення            float64
# Населення середнє                   float64
# Прогулянкова зона                     int64
# Якість покриття перед магазином       int64
# Стихійна торгівля                     int64
# Зона пікніка                          int64
# Церква                                int64
# dtype: object

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 0.5])
missings = pd.DataFrame(df.isnull().sum())
vars_with_missings = missings[missings > df.shape[0]*0.01].dropna().index.tolist()
sns.heatmap(df[vars_with_missings].isnull(),cbar=False, yticklabels=False, cmap='BuPu', ax=ax)
plt.show()

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                                    0
# Площадь загальна кв.м              0
# Этаж                               0
# Количество касс                    0
# Тип                                0
# Кількість відгуків в гуглі        30
# Количество чеков                   0
# Среднее количество единиц в чеке   7
# Середній дохід населення           5
# Населення середнє                  5
# Прогулянкова зона                  0
# Якість покриття перед магазином    0
# Стихійна торгівля                  0
# Зона пікніка                       0
# Церква                             0

# %%
#missing data is numeric, so let's recover it accordingly
dfm = df
imputer_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
dfm[['Кількість відгуків в гуглі']] = imputer_mean.fit_transform(dfm[['Кількість відгуків в гуглі']]).round()
dfm[['Среднее количество единиц в чеке']] = imputer_mean.fit_transform(dfm[['Среднее количество единиц в чеке']]).round()
dfm[['Середній дохід населення']] = imputer_mean.fit_transform(dfm[['Середній дохід населення']]).round()

# %%
dfm.describe()
# Out:
#        Площадь загальна кв.м  Этаж  Количество касс  \
# count              69.000000  69.0        69.000000
# mean               47.412725   1.0         1.231884
# std                37.862989   0.0         0.458416
# min                 4.000000   1.0         1.000000
# 25%                26.720000   1.0         1.000000
# 50%                32.300000   1.0         1.000000
# 75%                56.240000   1.0         1.000000
# max               232.300000   1.0         3.000000
#
#        Кількість відгуків в гуглі  Количество чеков  \
# count                   69.000000         69.000000
# mean                    42.898551       4084.097008
# std                     61.280489       2213.334346
# min                      1.000000        476.000000
# 25%                     12.000000       2344.000000
# 50%                     43.000000       3995.469796
# 75%                     43.000000       4826.000000
# max                    367.000000       9687.000000
#
#        Среднее количество единиц в чеке  Середній дохід населення  \
# count                         69.000000                 69.000000
# mean                           1.971014              11990.391304
# std                            0.240772               2474.008472
# min                            1.000000                  0.000000
# 25%                            2.000000              11060.000000
# 50%                            2.000000              12180.000000
# 75%                            2.000000              13300.000000
# max                            3.000000              16100.000000
#
#        Населення середнє  Прогулянкова зона  Якість покриття перед магазином  \
# count          64.000000          69.000000                        69.000000
# mean        19976.906250           0.188406                         0.115942
# std         13513.681268           0.393901                         0.322501
# min          1362.000000           0.000000                         0.000000
# 25%          8764.000000           0.000000                         0.000000
# 50%         19318.000000           0.000000                         0.000000
# 75%         30531.250000           0.000000                         0.000000
# max         54688.000000           1.000000                         1.000000
#
#        Стихійна торгівля  Зона пікніка     Церква
# count          69.000000     69.000000  69.000000
# mean            0.101449      0.043478   0.086957
# std             0.304135      0.205425   0.283836
# min             0.000000      0.000000   0.000000
# 25%             0.000000      0.000000   0.000000
# 50%             0.000000      0.000000   0.000000
# 75%             0.000000      0.000000   0.000000
# max             1.000000      1.000000   1.000000

# %%
dfm.corr()
# Out:
#                                   Площадь загальна кв.м  Этаж  \
# Площадь загальна кв.м                          1.000000   NaN
# Этаж                                                NaN   NaN
# Количество касс                                0.248200   NaN
# Кількість відгуків в гуглі                     0.241902   NaN
# Количество чеков                               0.359876   NaN
# Среднее количество единиц в чеке               0.279662   NaN
# Середній дохід населення                       0.006163   NaN
# Населення середнє                             -0.153781   NaN
# Прогулянкова зона                              0.041859   NaN
# Якість покриття перед магазином               -0.024872   NaN
# Стихійна торгівля                             -0.137155   NaN
# Зона пікніка                                  -0.014631   NaN
# Церква                                        -0.105498   NaN
#
#                                   Количество касс  Кількість відгуків в гуглі  \
# Площадь загальна кв.м                    0.248200                    0.241902
# Этаж                                          NaN                         NaN
# Количество касс                          1.000000                    0.353159
# Кількість відгуків в гуглі               0.353159                    1.000000
# Количество чеков                         0.672653                    0.324416
# Среднее количество единиц в чеке         0.061791                    0.359606
# Середній дохід населення                -0.136751                   -0.007150
# Населення середнє                        0.114544                    0.054679
# Прогулянкова зона                       -0.001180                    0.099499
# Якість покриття перед магазином         -0.085056                   -0.120686
# Стихійна торгівля                        0.250704                   -0.116219
# Зона пікніка                            -0.108635                   -0.055718
# Церква                                  -0.157249                   -0.078115
#
#                                   Количество чеков  \
# Площадь загальна кв.м                     0.359876
# Этаж                                           NaN
# Количество касс                           0.672653
# Кількість відгуків в гуглі                0.324416
# Количество чеков                          1.000000
# Среднее количество единиц в чеке          0.132629
# Середній дохід населення                 -0.282498
# Населення середнє                         0.315141
# Прогулянкова зона                         0.150017
# Якість покриття перед магазином          -0.080694
# Стихійна торгівля                         0.170010
# Зона пікніка                             -0.059134
# Церква                                   -0.143950
#
#                                   Среднее количество единиц в чеке  \
# Площадь загальна кв.м                                     0.279662
# Этаж                                                           NaN
# Количество касс                                           0.061791
# Кількість відгуків в гуглі                                0.359606
# Количество чеков                                          0.132629
# Среднее количество единиц в чеке                          1.000000
# Середній дохід населення                                 -0.126877
# Населення середнє                                         0.128753
# Прогулянкова зона                                         0.058428
# Якість покриття перед магазином                           0.043916
# Стихійна торгівля                                        -0.360905
# Зона пікніка                                              0.025854
# Церква                                                    0.037424
#
#                                   Середній дохід населення  Населення середнє  \
# Площадь загальна кв.м                             0.006163          -0.153781
# Этаж                                                   NaN                NaN
# Количество касс                                  -0.136751           0.114544
# Кількість відгуків в гуглі                       -0.007150           0.054679
# Количество чеков                                 -0.282498           0.315141
# Среднее количество единиц в чеке                 -0.126877           0.128753
# Середній дохід населення                          1.000000          -0.224019
# Населення середнє                                -0.224019           1.000000
# Прогулянкова зона                                -0.103296           0.456949
# Якість покриття перед магазином                  -0.129870          -0.120225
# Стихійна торгівля                                 0.047830          -0.019817
# Зона пікніка                                      0.227112           0.147618
# Церква                                            0.141101           0.008766
#
#                                   Прогулянкова зона  \
# Площадь загальна кв.м                      0.041859
# Этаж                                            NaN
# Количество касс                           -0.001180
# Кількість відгуків в гуглі                 0.099499
# Количество чеков                           0.150017
# Среднее количество единиц в чеке           0.058428
# Середній дохід населення                  -0.103296
# Населення середнє                          0.456949
# Прогулянкова зона                          1.000000
# Якість покриття перед магазином           -0.174485
# Стихійна торгівля                         -0.161894
# Зона пікніка                               0.079017
# Церква                                     0.114377
#
#                                   Якість покриття перед магазином  \
# Площадь загальна кв.м                                   -0.024872
# Этаж                                                          NaN
# Количество касс                                         -0.085056
# Кількість відгуків в гуглі                              -0.120686
# Количество чеков                                        -0.080694
# Среднее количество единиц в чеке                         0.043916
# Середній дохід населення                                -0.129870
# Населення середнє                                       -0.120225
# Прогулянкова зона                                       -0.174485
# Якість покриття перед магазином                          1.000000
# Стихійна торгівля                                        0.028248
# Зона пікніка                                            -0.077209
# Церква                                                   0.209550
#
#                                   Стихійна торгівля  Зона пікніка    Церква
# Площадь загальна кв.м                     -0.137155     -0.014631 -0.105498
# Этаж                                            NaN           NaN       NaN
# Количество касс                            0.250704     -0.108635 -0.157249
# Кількість відгуків в гуглі                -0.116219     -0.055718 -0.078115
# Количество чеков                           0.170010     -0.059134 -0.143950
# Среднее количество единиц в чеке          -0.360905      0.025854  0.037424
# Середній дохід населення                   0.047830      0.227112  0.141101
# Населення середнє                         -0.019817      0.147618  0.008766
# Прогулянкова зона                         -0.161894      0.079017  0.114377
# Якість покриття перед магазином            0.028248     -0.077209  0.209550
# Стихійна торгівля                          1.000000     -0.071638 -0.103695
# Зона пікніка                              -0.071638      1.000000 -0.065795
# Церква                                    -0.103695     -0.065795  1.000000

# %%
dfm.Этаж.value_counts()
# Out:
# 1    69
# Name: Этаж, dtype: int64

# %%
corrmat = dfm.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %% [markdown]
# # Найбольшая корреляция между количеством чеков и количеством касс

# %%
dfs = dfm[['Тип']]
info = []
for column in dfs.columns:
        vals = {"col": column,
                "nunique": dfs[column].nunique(),
                "unique": dfs[column].unique(),
                "type": dfs[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                                    unique    type
# 0  Тип        5  [Light, light, Standart, Micro, Premium]  object

# %%
type_ = {'МАФ':0,'Light':0,'Standart':1}
dfm['Тип'] = dfm['Тип'].map(type_)
dfm
# Out:
#     Площадь загальна кв.м  Этаж  Количество касс  Тип  \
# 0                    9.00     1                1  NaN
# 1                   30.00     1                1  NaN
# 2                   15.00     1                1  NaN
# 3                   20.00     1                1  NaN
# 4                   30.00     1                1  NaN
# ..                    ...   ...              ...  ...
# 64                  51.77     1                2  NaN
# 65                  27.26     1                1  NaN
# 66                 148.91     1                1  NaN
# 67                  50.93     1                2  NaN
# 68                  30.00     1                1  NaN
#
#     Кількість відгуків в гуглі  Количество чеков  \
# 0                         43.0             659.0
# 1                          8.0            1518.0
# 2                         43.0             476.0
# 3                         43.0            1310.0
# 4                         43.0            2029.0
# ..                         ...               ...
# 64                         4.0            6884.0
# 65                         3.0            4721.0
# 66                        12.0            3286.0
# 67                        17.0            3963.0
# 68                        12.0            4200.0
#
#     Среднее количество единиц в чеке  Середній дохід населення  \
# 0                                2.0                   15610.0
# 1                                2.0                   12600.0
# 2                                2.0                   12600.0
# 3                                2.0                   13930.0
# 4                                2.0                   16030.0
# ..                               ...                       ...
# 64                               2.0                    8750.0
# 65                               2.0                   13300.0
# 66                               2.0                   11060.0
# 67                               2.0                   11900.0
# 68                               2.0                   11060.0
#
#     Населення середнє  Прогулянкова зона  Якість покриття перед магазином  \
# 0             11298.0                  0                                0
# 1             18903.0                  0                                0
# 2             20252.0                  0                                0
# 3              2540.0                  0                                0
# 4              6896.0                  0                                0
# ..                ...                ...                              ...
# 64            42781.0                  0                                0
# 65            32400.0                  0                                0
# 66            29287.0                  1                                0
# 67             5705.0                  0                                0
# 68            11085.0                  0                                0
#
#     Стихійна торгівля  Зона пікніка  Церква
# 0                   0             0       1
# 1                   0             0       0
# 2                   0             0       0
# 3                   0             0       0
# 4                   0             0       0
# ..                ...           ...     ...
# 64                  0             0       0
# 65                  0             0       0
# 66                  0             0       0
# 67                  0             0       0
# 68                  0             0       0
#
# [69 rows x 14 columns]

# %%
corrmat = dfm.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat[['Тип',]], annot=True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:198: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:203: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
sns.pairplot(dfm)

# %%
feature_name = ['Количество касс','Среднее количество единиц в чеке','Зона пікніка','Стихійна торгівля']
X =dfm[feature_name]
y = dfm['Количество чеков']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
f1 = ['Количество касс']

from sklearn.linear_model import LinearRegression
sr = LinearRegression().fit(X_train[f1], y_train)

# Getting parameters
sr.coef_, sr.intercept_
# Out:
# (array([3142.39059221]), 278.94873097904974)

# %%
# Predicting the Test set results
y_pred = sr.predict(X_test[f1])

# Coefficient of determination R^2
sr.score(X_train[f1], y_train).round(3), sr.score(X_test[f1], y_test).round(3)
# Out:
# (0.446, 0.423)

# %%
print(mean_squared_error(y_train, sr.predict(X_train[f1]), squared=False).round(2))
mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# 1664.14
# 1476.99

# %%
# Fitting Linear Regression based on 5 features to the Training set

from sklearn.linear_model import LinearRegression
mr = LinearRegression().fit(X_train, y_train)

# Getting parameters
mr.coef_, mr.intercept_
# Out:
# (array([3015.0264946 ,  641.9867527 , -547.84876787,  334.56886118]),
#  -849.6512321272721)

# %%
# Predicting the Test set results
y_pred2 = mr.predict(X_test)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3), mr.score(X_test, y_test).round(3)
# Out:
# (0.452, 0.419)

# %%
print(mean_squared_error(y_train, mr.predict(X_train), squared=False).round(2))
mean_squared_error(y_test, y_pred2, squared=False).round(2)
# Out:
# 1654.99
# 1481.24

# %%
# Checking p-values
X1 = sm.add_constant(X_train)
mr1 = sm.OLS(y_train, X1).fit()
mr1.pvalues
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
# const                               7.323071e-01
# Количество касс                     6.306559e-07
# Среднее количество единиц в чеке    6.113680e-01
# Зона пікніка                        6.650255e-01
# Стихійна торгівля                   7.246291e-01
# dtype: float64

# %%
mr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:       Количество чеков   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.409
# Method:                 Least Squares   F-statistic:                     10.33
# Date:                Mon, 27 Dec 2021   Prob (F-statistic):           3.56e-06
# Time:                        18:50:28   Log-Likelihood:                -485.68
# No. Observations:                  55   AIC:                             981.4
# Df Residuals:                      50   BIC:                             991.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                             -849.6512   2470.092     -0.344      0.732   -5810.977    4111.675
# Количество касс                   3015.0265    528.652      5.703      0.000    1953.197    4076.856
# Среднее количество единиц в чеке   641.9868   1255.514      0.511      0.611   -1879.786    3163.760
# Зона пікніка                      -547.8488   1257.783     -0.436      0.665   -3074.180    1978.482
# Стихійна торгівля                  334.5689    944.399      0.354      0.725   -1562.313    2231.451
# ==============================================================================
# Omnibus:                        0.885   Durbin-Watson:                   1.729
# Prob(Omnibus):                  0.643   Jarque-Bera (JB):                0.311
# Skew:                           0.108   Prob(JB):                        0.856
# Kurtosis:                       3.299   Cond. No.                         30.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Fitting Polynomial Regression to the dataset
X_train_p = PolynomialFeatures().fit_transform(X_train)
X_test_p = PolynomialFeatures().fit_transform(X_test)

pr = LinearRegression().fit(X_train, y_train)

# Getting parameters
pr.coef_, pr.intercept_
# Out:
# (array([3015.0264946 ,  641.9867527 , -547.84876787,  334.56886118]),
#  -849.6512321272721)

# %%
# Predicting the Test set results
y_pred = pr.predict(X_test)

# Coefficient of determination R^2
pr.score(X_train, y_train).round(3), pr.score(X_test, y_test).round(3)
# Out:
# (0.452, 0.419)

# %%
# Mean squared error
print(mean_squared_error(y_train, pr.predict(X_train), squared=False).round(2))
mean_squared_error(y_test, y_pred, squared=False).round(2)
# Out:
# 1654.99
# 1481.24

# %%
# Fitting Random Forest to the Training set
rf = RandomForestRegressor(n_estimators = 2, max_leaf_nodes = 25, random_state = 10).fit(X_train, y_train)

# Predicting the Test set results
rf_y_pred = rf.predict(X_test)

# Metrics
metrics(X_train, X_test, y_train, y_test, rf_y_pred, rf).round(2)
# Out:
#           RMSE    R2
# Train  1663.40  0.45
# Test   1673.66  0.26

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature_, round(importance, 2)) for feature_, importance in zip(feature_name, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Количество касс      Importance: 0.93
# Variable: Среднее количество единиц в чеке Importance: 0.04
# Variable: Зона пікніка         Importance: 0.01
# Variable: Стихійна торгівля    Importance: 0.01
